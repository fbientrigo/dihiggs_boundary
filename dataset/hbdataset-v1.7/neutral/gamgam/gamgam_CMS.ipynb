# %%
import pandas as pd
import numpy as np
from Higgs.tools.ImplementationUtils import (
    implementChannelLimit,
    read_csv_from_web,
    implementChannelWidthLimit,
    fromHB5Table1,
    readHEPDataCsv,
)
from Higgs import predictions as HP
from Higgs import bounds as HB
from Higgs.tools.LimitValidation import validateChannelLimit, validateChannelWidthLimit
import os, sys

sys.path.insert(0, os.path.dirname(os.path.dirname(os.getcwd())))
import MassResolutions as resolution

# %% [markdown]
# # CMS 13TeV LHC

# %% [markdown]
# ## `H > gamgam` heavy [2405.09320](https://arxiv.org/abs/2405.09320)

# %%
dfs = readHEPDataCsv(
    "https://www.hepdata.net/download/table/ins2787227/Fig.%204d%20Observed%20J%3D0%202D%20limits/1/csv"
)

# %%
dgs = readHEPDataCsv(
    "https://www.hepdata.net/download/table/ins2787227/Fig.%204c%20Expected%20J%3D0%202D%20limits/1/csv"
)

# %%
df = pd.DataFrame()
df['m'] = dfs[0]['$m_{G}$ [GeV]']
df['normWidth'] = dfs[0]['$\\Gamma/m$ [%]']
df['obs'] = dfs[0]['Obs. upper limit [95%CL]']
df['exp'] = dgs[0]['Exp. upper limit [95%CL]']
df.obs *= 1e-3  # fb to pb
df.exp *= 1e-3
df
# Out:
#            m  normWidth       obs       exp
# 0      605.0     0.1875  0.001564  0.001319
# 1      605.0     0.5340  0.001651  0.001401
# 2      605.0     0.8805  0.001747  0.001492
# 3      605.0     1.2270  0.001849  0.001591
# 4      605.0     1.9250  0.001947  0.001690
# ...      ...        ...       ...       ...
# 3515  4995.0     1.2270  0.000033  0.000035
# 3516  4995.0     1.9250  0.000033  0.000035
# 3517  4995.0     2.9750  0.000033  0.000036
# 3518  4995.0     4.0250  0.000033  0.000036
# 3519  4995.0     5.0750  0.000034  0.000036
#
# [3520 rows x 4 columns]

# %%
prods = ["H", "Htt", "vbfH", "HZ", "HW"]
limitFile = implementChannelWidthLimit(
    "2405.09320",
    {"channels": [[p, "gamgam"] for p in prods]},
    "https://www.hepdata.net/record/ins2787227",
    df,
    massResolution=resolution.gamgam["default"]
)
lim = HB.Limit(limitFile)
# Out:
# Looks good. Saving this to comb_LHC13_CMS_138.json

# %% [markdown]
# ## `H > gamgam` light, SM-like [1811.08459](https://arxiv.org/abs/1811.08459)
# Note: this is the search with the 96GeV excess
#
# Superseeded by 2405.18149.

# %%
# dfExp = read_csv_from_web(
#     "https://www.hepdata.net/download/table/ins1704494/Figure%206/1/csv",
#     comment="#",
#     skiprows=549,
#     names=["m", "exp", "unc+", "unc-"],
# )

# df = read_csv_from_web(
#     "https://www.hepdata.net/download/table/ins1704494/Figure%206/1/csv",
#     comment="#",
#     skiprows=10,
#     skipfooter=817 - 277,
#     engine="python",
#     names=["m", "obs"],
# )

# assert np.allclose(df.m, dfExp.m)
# df["exp"] = dfExp.exp
# limitFile = implementChannelLimit(
#     "1811.08459",
#     {"channels": [[p, "gamgam"] for p in ["H", "vbfH", "HZ", "HW", "Htt"]]},
#     "https://doi.org/10.17182/hepdata.91266.v1/t7",
#     df,
#     collider="LHC13",
#     luminosity=19.7 + 35.9,  # 8 TeV + 13 TeV
#     constraints={"modelLike": "SMHiggsInterp", "process": "signal"},
#     massResolution=resolution.gamgam["125"],
#     normalization={"reference": "SMHiggsInterp", "process": "signal"},
# )
# lim = HB.Limit(limitFile)
# fig, ax = validateChannelLimit(lim)

# %% [markdown]
# ## `H > gamgam` light, SM-like [2405.18149](https://arxiv.org/abs/2405.18149)
# Note: this is the search with the 95GeV excess
#
# Superseeds 1811.08459.

# %%
dfs = readHEPDataCsv(
    "https://www.hepdata.net/download/table/ins2791038/Figure%205b/1/csv",
)

# %%
assert np.allclose(
    dfs[0]['di-photon resonance mass [GeV]'],
    dfs[1]['di-photon resonance mass [GeV]'])
df = pd.DataFrame({
    'm': dfs[0]['di-photon resonance mass [GeV]'],
    'obs': dfs[0]['Cross section upper limit at 95% CL [pb]'],
    'exp': dfs[1]['Cross section upper limit at 95% CL [pb]']
})
limitFile = implementChannelLimit(
    "2405.18149",
    {"channels": [[p, "gamgam"] for p in ["H", "vbfH", "HZ", "HW", "Htt"]]},
    "https://doi.org/10.17182/hepdata.150508.v1/t2",
    df,
    collider="LHC13",
    luminosity=132,  # Only Run 2 13 TeV
    constraints={"modelLike": "SMHiggsInterp", "process": "signal"},
    massResolution=resolution.gamgam["125"],
    normalization={"reference": "SMHiggsInterp", "process": "signal"},
)
lim = HB.Limit(limitFile)
# Out:
# Multiple different luminosity values: [54.4, 41.5, 36.3] using 54.4 unless you set it manually
# Looks good. Saving this to comb_LHC13_CMS_132.json

# %% [markdown]
# # CMS 8TeV LHC

# %% [markdown]
# ## `H>gamgam` full Run1 hSM combination [CMS-PAS-HIG-13-001](https://cds.cern.ch/record/1530524?ln=en)

# %%
df = fromHB5Table1("13001_CMS_H-gaga_MVA_25fb-1", "CMS")
limitFile = implementChannelLimit(
    1230222,
    {"channels": [[p, "gamgam"] for p in ["H", "vbfH", "HZ", "HW", "Htt"]]},
    "Fig. 5a",
    df,
    constraints={"modelLike": "SMHiggsInterp", "process": "signal"},
    massResolution=resolution.gamgam["125"],
    luminosity=5.1 + 19.6,
    normalization={"reference": "SMHiggsInterp", "process": "signal"},
    suppressLimit=True,
    suppressLimitMassRange=[125 - (resolution.gamgam["125"]['absolute'] + 125*resolution.ZZ["4l"]['relative']),
                            125 + (resolution.gamgam["125"]['absolute'] + 125*resolution.gamgam["125"]['relative'])],
)
lim = HB.Limit(limitFile)
fig, ax = validateChannelLimit(lim)
# Out:
# No arxiv eprint found.
# Looks good. Saving this to comb_LHC8_CMS_25.json
# using effective coupling input for SM-normalized limit

# %% [markdown]
# ## low-mass hSM 8TeV [CMS-PAS-HIG-14-037](https://cds.cern.ch/record/2063739?ln=en)

# %%
df = fromHB5Table1("14037_CMS_H-gaga_19.7fb-1", "CMS")
prods = ["H", "vbfH", "HZ", "HW", "Htt"]
limitFile = implementChannelLimit(
    1401518,
    {"channels": [[p, "gamgam"] for p in prods]},
    "Fig. 4",
    df,
    massResolution=resolution.gamgam["default"],
    luminosity=19.7,
    prefix="comb_lowMass",
    constraints={"modelLike": "SMHiggs", "process": "signal"},
)
lim = HB.Limit(limitFile)


def smLikeDistributeRate(h, rate):
    smrate = sum(
        (
            HP.SMHiggs(h.mass()).channelRate(lim.collider(), p, "gamgam")
            for p in prods
        )
    )
    HP.effectiveCouplingInput(h, HP.scaledSMlikeEffCouplings(np.sqrt(rate / smrate)))


fig, ax = validateChannelLimit(lim, setAdditionalRates=smLikeDistributeRate)
# Out:
# No arxiv eprint found.
# Looks good. Saving this to comb_lowMass_LHC8_CMS_20.json

# %% [markdown]
# ## high mass `pp>H>gamgam` LHC8, width-dep [1506.02301](https://arxiv.org/abs/1506.02301)

# %%
dfExp = read_csv_from_web(
    "https://twiki.cern.ch/twiki/pub/CMSPublic/Hig14006TWiki/limitsResults_2D_Exp.txt",
    sep=r"\s+",
    names=["mass:", "m", "Gamma:", "width", "UL:", "exp"],
)
dfObs = read_csv_from_web(
    "https://twiki.cern.ch/twiki/pub/CMSPublic/Hig14006TWiki/limitsResults_2D_Obs.txt",
    sep=r"\s+",
    names=["mass:", "m", "Gamma:", "width", "UL:", "obs"],
)
assert np.allclose(dfExp.m, dfObs.m)
assert np.allclose(dfExp.width, dfObs.width)
df = dfObs.copy()
df["exp"] = dfExp.exp
del df["mass:"]
del df["Gamma:"]
del df["UL:"]
df.loc[(df.width == 0.1), "width"] = 0
df["normWidth"] = df.width / df.m
df.normWidth = np.round(df.normWidth, 2)

limitFile = implementChannelWidthLimit(
    "1506.02301",
    {"channels": [["H", "gamgam"]]},
    "https://twiki.cern.ch/twiki/bin/view/CMSPublic/Hig14006TWiki",
    df,
    massResolution=resolution.gamgam["default"],
)
lim = HB.Limit(limitFile)
validateChannelWidthLimit(lim)
# Out:
# Looks good. Saving this to H_LHC8_CMS_20.json
