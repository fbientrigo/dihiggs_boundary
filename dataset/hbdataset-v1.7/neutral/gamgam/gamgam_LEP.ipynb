# %%
import pandas as pd
import numpy as np
from Higgs.tools.ImplementationUtils import implementChannelLimit, fromHB5Table1
from Higgs import bounds as HB
from Higgs.tools.LimitValidation import validateChannelLimit
import os, sys

sys.path.insert(0, os.path.dirname(os.path.dirname(os.getcwd())))
import MassResolutions as resolution

# %% [markdown]
# # LEP `ZH -> gamgam` [CERN-ALEPH-2002-019](http://cds.cern.ch/record/644922)

# %%
df = fromHB5Table1("LEP_h-gammagamma", "LEP")

process = {"channels": [["eeHZ", "gamgam"]]}
limitFile = implementChannelLimit(
    1659744,
    process,
    "Fig 5",
    df,
    collider="LEP",
    experiment="LEPComb",
    luminosity=0,  # they don't say...
    massResolution=resolution.LEPZH,
)
lim = HB.Limit(limitFile)
fig, ax = validateChannelLimit(lim)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_698793/989776364.py in <module>
#       2
#       3 process = {"channels": [["eeHZ", "gamgam"]]}
# ----> 4 limitFile = implementChannelLimit(
#       5     1659744,
#       6     process,
#
# TypeError: implementChannelLimit() got an unexpected keyword argument 'reference'
