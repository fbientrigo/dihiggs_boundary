# %%
import pandas as pd
import numpy as np
from Higgs.tools.ImplementationUtils import implementChannelLimit, fromHB5Table1
from Higgs import bounds as HB
from Higgs.tools.LimitValidation import validateChannelLimit
import os, sys

sys.path.insert(0, os.path.dirname(os.path.dirname(os.getcwd())))
import MassResolutions as resolution

# %% [markdown]
# # LEP `ee -> ZH, H -> tautau` [hep-ex/0306033](https://arxiv.org/pdf/hep-ex/0306033)

# %%
df = fromHB5Table1("lep210_htt_interpol", "LEP")

process = {"channels": [["eeHZ", "tautau"]]}
limitFile = implementChannelLimit(
    619171,
    process,
    "Fig 10c",
    df,
    idSuffix=3,
    luminosity=2.5,
    massResolution=resolution.LEPZH,
)
lim = HB.Limit(limitFile)
fig, ax = validateChannelLimit(lim)
# Out:
# Could not detect luminosity
# Looks good. Saving this to eeHZ_LEP_LEPComb_2.json

# %% [markdown]
# # DELPHI `ee -> bbH, H -> tautau` [hep-ex/0410017](https://arxiv.org/pdf/hep-ex/0410017)

# %%
df = fromHB5Table1("Delphi_yuk_h_bbtautau", "LEP")
limitFile = implementChannelLimit(
    661247,
    {"channels": [["eeHbb", "tautau"]]},
    "Fig 10(top)",
    df,
    idSuffix=3,
    luminosity=0.0794 + 0.6112,
    massResolution=resolution.LEPZH,
    constraints={"CPValue": "even"},
)
lim = HB.Limit(limitFile)
fig, ax = validateChannelLimit(lim, cp="even")
# Out:
# Could not detect luminosity
# Looks good. Saving this to eeHbb_LEP_DELPHI_1.json

# %% [markdown]
# # DELPHI `ee -> bbA, A -> tautau` [hep-ex/0410017](https://arxiv.org/pdf/hep-ex/0410017)

# %%
df = fromHB5Table1("Delphi_yuk_a_bbtautau", "LEP")
limitFile = implementChannelLimit(
    661247,
    {"channels": [["eeHbb", "tautau"]]},
    "Fig 10(bottom)",
    df,
    idSuffix=4,
    luminosity=0.0794 + 0.6112,
    massResolution=resolution.LEPZH,
    constraints={"CPValue": "odd"},
    prefix="eeAbb",
)
lim = HB.Limit(limitFile)
fig, ax = validateChannelLimit(lim, cp="odd")
# Out:
# Could not detect luminosity
# Looks good. Saving this to eeAbb_LEP_DELPHI_1.json

# %% [markdown]
# # DELPHI `ee -> tautau H, H -> tautau` [hep-ex/0410017](https://arxiv.org/pdf/hep-ex/0410017)

# %%
df = fromHB5Table1("Delphi_yuk_h_tautautautau", "LEP")
limitFile = implementChannelLimit(
    661247,
    {"channels": [["eeHtautau", "tautau"]]},
    "Fig 11(top)",
    df,
    idSuffix=5,
    luminosity=0.0794 + 0.6112,
    massResolution=resolution.LEPZH,
    constraints={"CPValue": "even"},
)
lim = HB.Limit(limitFile)
fig, ax = validateChannelLimit(lim, cp="even")
# Out:
# Could not detect luminosity
# Looks good. Saving this to eeHtautau_LEP_DELPHI_1.json

# %% [markdown]
# # DELPHI `ee -> tautau A, A -> tautau` [hep-ex/0410017](https://arxiv.org/pdf/hep-ex/0410017)

# %%
df = fromHB5Table1("Delphi_yuk_a_tautautautau", "LEP")
limitFile = implementChannelLimit(
    661247,
    {"channels": [["eeHtautau", "tautau"]]},
    "Fig 11(top)",
    df,
    idSuffix=6,
    luminosity=0.0794 + 0.6112,
    massResolution=resolution.LEPZH,
    constraints={"CPValue": "odd"},
    prefix="eeAtautau",
)
lim = HB.Limit(limitFile)
fig, ax = validateChannelLimit(lim, cp="odd")
# Out:
# Could not detect luminosity
# Looks good. Saving this to eeAtautau_LEP_DELPHI_1.json

# %% [markdown]
# # OPAL `ee -> bb H, H -> tautau` [hep-ex/0111010](https://arxiv.org/pdf/hep-ex/0111010)

# %%
df = fromHB5Table1("OPAL_yuk_h_bbtautau", "LEP")
limitFile = implementChannelLimit(
    565438,
    {"channels": [["eeHbb", "tautau"]]},
    "Tab 8",
    df,
    idSuffix=1,
    luminosity=0.1131,
    massResolution={"absolute": 1, "relative": 0},  # guess from bin width
    constraints={"CPValue": "even"},
)
lim = HB.Limit(limitFile)
fig, ax = validateChannelLimit(lim, cp="even")
# Out:
# Could not detect luminosity
# Looks good. Saving this to eeHbb_LEP_OPAL_0.json

# %% [markdown]
# # OPAL `ee -> bb A, A -> tautau` [hep-ex/0111010](https://arxiv.org/pdf/hep-ex/0111010)

# %%
df = fromHB5Table1("OPAL_yuk_a_bbtautau", "LEP")
limitFile = implementChannelLimit(
    565438,
    {"channels": [["eeHbb", "tautau"]]},
    "Tab 8",
    df,
    idSuffix=2,
    luminosity=0.1131,
    massResolution={"absolute": 1, "relative": 0},  # guess from bin width
    constraints={"CPValue": "odd"},
    prefix="eeAbb",
)
lim = HB.Limit(limitFile)
fig, ax = validateChannelLimit(lim, cp="odd")
# Out:
# Could not detect luminosity
# Looks good. Saving this to eeAbb_LEP_OPAL_0.json
