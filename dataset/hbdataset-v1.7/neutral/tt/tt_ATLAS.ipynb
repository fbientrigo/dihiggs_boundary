# %%
import os
import pandas as pd
from Higgs import bounds as HB
from Higgs.tools.ImplementationUtils import (
    implementChannelLimit,
    fromHB5Table1,
    readHEPDataCsv,
)
from Higgs.tools.LimitValidation import validateChannelLimit

sys.path.insert(0, os.path.dirname(os.path.dirname(os.getcwd())))
import MassResolutions as resolution

# %% [markdown]
# # ATLAS 13TeV LHC

# %% [markdown]
# ## ## ttH > tt tt, CP-even and CP-odd [2211.01136](https://inspirehep.net/literature/2175533)
#
# !! Cannot be implemented since the XS limit plot is only valid for a CP-even and a CP-odd scalar with the same mass

# %%
# df = pd.DataFrame(
#     data={
#         "m": [400, 500, 600, 700, 800, 900, 1000],
#         "obs": [0.0144, 0.0123, 0.00989, 0.00972, 0.00818, 0.00720, 0.00619],
#         "exp": [0.0104, 0.00875, 0.00740, 0.00712, 0.00596, 0.00539, 0.00464],
#     }
# )

# limitFile = implementChannelLimit(
#     "2211.01136",
#     {"channels": [["Htt", "tt"]]},
#     "Fig. 7",
#     df,
#     luminosity=139,
#     massResolution=resolution.tt["tttt"],
#     prefix="tttt",
# )

# lim = HB.Limit(limitFile)
# fig, ax = validateChannelLimit(lim)
