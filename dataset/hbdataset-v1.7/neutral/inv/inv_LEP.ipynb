# %%
import pandas as pd
import numpy as np
from Higgs.tools.ImplementationUtils import implementChannelLimit, fromHB5Table1
from Higgs import bounds as HB
from Higgs.tools.LimitValidation import validateChannelLimit
import os, sys

sys.path.insert(0, os.path.dirname(os.path.dirname(os.getcwd())))
import MassResolutions as resolution

# %% [markdown]
# # LEP `ZH->inv` [hep-ex/0107032](https://arxiv.org/abs/hep-ex/0107032)

# %%
df = fromHB5Table1("LEP_h-invisible", "LEP")

limitFile = implementChannelLimit(
    559835,
    {"channels": [["eeHZ", "inv"]]},
    "Fig 4",
    df,
    luminosity=0.215 + 0.225 + 0.217 + 0.21,
    massResolution=resolution.LEPZH,
)
lim = HB.Limit(limitFile)
fig, ax = validateChannelLimit(lim)
# Out:
# Could not detect luminosity
# Looks good. Saving this to eeHZ_LEP_LEPComb_1.json

# %% [markdown]
# # DELPHI `ZH->inv` [hep-ex/0401022](https://arxiv.org/abs/hep-ex/0401022)

# %%
df = fromHB5Table1("Delphi_h-invisible", "LEP")

limitFile = implementChannelLimit(
    636842,
    {"channels": [["eeHZ", "inv"]]},
    "Fig 14",
    df,
    luminosity=0.589,
    collider="LEP",
    massResolution=resolution.LEPZH,
)
lim = HB.Limit(limitFile)
fig, ax = validateChannelLimit(lim)
# Out:
# Could not detect luminosity
# Looks good. Saving this to eeHZ_LEP_DELPHI_1.json

# %% [markdown]
# # L3 `ZH->inv` [hep-ex/0501033](https://arxiv.org/abs/hep-ex/0501033)

# %%
df = fromHB5Table1("L3_h-invisible", "LEP")

limitFile = implementChannelLimit(
    668596,
    {"channels": [["eeHZ", "inv"]]},
    "Fig 6c",
    df,
    massResolution=resolution.LEPZH,
)
lim = HB.Limit(limitFile)
fig, ax = validateChannelLimit(lim)
# Out:
# Looks good. Saving this to eeHZ_LEP_L3_1.json

# %% [markdown]
# # OPAL `ZH->inv` [0707.0373](https://arxiv.org/abs/0707.0373)

# %%
df = fromHB5Table1("OPAL_h-invisible", "LEP")

limitFile = implementChannelLimit(
    754788,
    {"channels": [["eeHZ", "inv"]]},
    "Fig 5",
    df,
    luminosity=0.66,
    massResolution=resolution.LEPZH,
)
lim = HB.Limit(limitFile)
fig, ax = validateChannelLimit(lim)
# Out:
# Could not detect luminosity
# Looks good. Saving this to eeHZ_LEP_OPAL_1.json
